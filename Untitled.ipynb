# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as sns
import pandas as pd
import statistics
df = pd.read_excel('Data_Train.xlsx')
df.head()
df['Additional_Info'].unique()
copied_one = df.copy()

# %%
df_test = pd.read_excel('Test_set.xlsx')
df_test
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL → BOM → COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU → MAA → BLR    06:20         10:20       4h      1 stop
# ...

# %%
result = [df,df_test]
df = pd.concat(result)
df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
# df['Date_of_Journey'].as
df['journey_date'] = df['Date_of_Journey'].str.split('/').str[0]
df['journey_month'] = df['Date_of_Journey'].str.split('/').str[1]
df['journey_year'] = df['Date_of_Journey'].str.split('/').str[2]
# df.head(2)
# df.drop(columns='Date_of_Journey',axis=1,inplace=True)
# df.drop(columns='',axis=1,inplace=True)
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info   Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info  3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info  7662.0
#
#   journey_date journey_month journey_year
# 0           24            03         2019
# 1            1            05         2019

# %%
df.head(2)
df['journey_date']=df['journey_date'].astype(int)
df['journey_month']=df['journey_month'].astype(int)
df['journey_year']=df['journey_year'].astype(int)

# %%
df.isnull().sum()
df['Price'].median()
# Out:
# 8372.0

# %%
df['Arrival']= df['Arrival_Time'].str.split(' ').str[0]
df.head(2)
df['Arrival_hour'] = df['Arrival'].apply(lambda x:x.split(':')[0])
df['Arrival_min'] = df['Arrival'].apply(lambda x:x.split(':')[1])
df['Arrival_hour']=df['Arrival_hour'].astype(int)
df['Arrival_min']=df['Arrival_min'].astype(int)
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info   Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info  3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info  7662.0
#
#    journey_date  journey_month  journey_year Arrival  Arrival_hour  \
# 0            24              3          2019   01:10             1
# 1             1              5          2019   13:15            13
#
#    Arrival_min
# 0           10
# 1           15

# %%
# df.isnull().sum()
# plt.scatter(x='Price',y='journey_month',data=df)
# plt.show()
# df['Arrival']= df['Dep_Time'].str.split(' ').str[0]
df.head(2)
df['Dep_hour'] = df['Dep_Time'].apply(lambda x:x.split(':')[0])
df['Dep_min'] = df['Dep_Time'].apply(lambda x:x.split(':')[1])
df['Dep_hour']=df['Dep_hour'].astype(int)
df['Dep_min']=df['Dep_min'].astype(int)
df.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0
#
#    journey_date  journey_month  journey_year Arrival  Arrival_hour  \
# 0            24              3          2019   01:10             1
# 1             1              5          2019   13:15            13
# 2             9              6          2019   04:25             4
#
#    Arrival_min  Dep_hour  Dep_min
# 0           10        22       20
# ...

# %%
# df['Total_Stops'].dropna()
# df['Total_Stops'].unique()
# df['Total_Stops']=df['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4,'nan':1})
# df[df['Total_Stops'].isnull()]
df['Stops']=df['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4,'NaN':1})
df.isnull().sum()
df.drop(df[df['Stops'].isnull()],axis=1)
df.isnull().sum()
# Out:
# Airline               0
# Date_of_Journey       0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# journey_date          0
# journey_month         0
# journey_year          0
# Arrival               0
# Arrival_hour          0
# Arrival_min           0
# Dep_hour              0
# Dep_min               0
# Stops                 1
# dtype: int64

# %%
# gkk = df.groupby(['Route', 'journey_month'])
# print(df.groupby(['Price']).mean())
# df['Route'].unique()
# route_price = route_priced.to_frame()
# route_price['Price']
# routes = df['Route'].unique()
# route_price['routes'] =routes
# route_price['D'] = pd.Series(routes)
# plt.plot(x='')
# route_price['Price'].size
# routes.astype(str)
# route_priced.to_frame()
# route  = pd.DataFrame(route_priced)
# route.to_csv('routes_price.csv')



# route_priced = df.groupby('Route')['Price'].sum()
# rp =pd.read_csv('routes_price.csv')
# rp
# routess = rp.Route.value_counts().index
# pricess = rp.Price.value_counts().values
# plt.pie(pricess[:10],labels=routess[:10],data=rp,autopct='%1.1f%%')
# plt.show()

# %%
# sorts = rp['Price'].sort_values
# rp[rp['Price'] == 26027193.0]


# sorts

# %%
# route_priced = df.groupby('Route')['Price'].sum()
# route_priced

# %%
# ahm_to_cul = df[df['Route'] =='BLR → AMD → DEL']
# ahm_to_cul['Price'].sum()

# %%
# df.head(3)
# Airline_price  = df.groupby('Airline')['Price'].sum()
# Airline_cost = Airline_price.values
# Airline_name = Airline_price.index
# Airline_name
# fig = plt.figure(figsize = (25, 25))
# plt.bar(Airline_name,Airline_cost,color ='maroon')
# plt.show()


# Jet airways make most revenue among all airways

# %%
# Busiest airplane among all


# Airlines = df.groupby(['Airline'])['Airline'].count()
# Airline_name = Airlines.index
# Airlinr_val = Airlines.values
# fig = plt.figure(figsize = (25, 25))
# plt.plot(Airline_name,Airlinr_val,color= "blue")
# plt.show()

split = df['Duration'].str.split('h').str[0]
# mins = df['Duration'].str.split(' ').str[1].str[0]
df['aprox_time']=df['Duration'].str.split('h').str[0]
# split
# df[df['aprox_time'] == '5m']
df.drop(6474,axis=0,inplace=True)
df.drop(2660,axis=0,inplace=True)
df['aprox_time'] = df['aprox_time'].astype(int)

# %%
df.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  ...  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info  ...
# 1    05:50         13:15   7h 25m     2 stops         No info  ...
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  ...
#
#    journey_date  journey_month  journey_year  Arrival Arrival_hour  \
# 0            24              3          2019    01:10            1
# 1             1              5          2019    13:15           13
# 2             9              6          2019    04:25            4
#
#    Arrival_min  Dep_hour  Dep_min  Stops  aprox_time
# 0           10        22       20    0.0           2
# ...

# %%
plt.scatter(df['aprox_time'],df['Price'],color="red")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
df['Airline']=labelencoder.fit_transform(df['Airline'])
df['Source']=labelencoder.fit_transform(df['Source'])
df['Destination']=labelencoder.fit_transform(df['Destination'])
df['Additional_Info']=labelencoder.fit_transform(df['Additional_Info'])
